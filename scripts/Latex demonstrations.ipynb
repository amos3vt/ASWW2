# %%
import torch
from pytorch_pretrained_bert import BertTokenizer, BertModel

# %%
tokenizer = BertTokenizer.from_pretrained('bert-base-uncased')

# %% [markdown]
# For the tokenizer to work properly we need to add some tokens of our own.  One being "[CLS]" which marks the beginning of a text entry and the other being "[SEP]" which is the token that we put in between sentences within the same text entry.  So lets put together the following text.  "We are learning something very cool right now. Pay attention". After we put the tokens in the right places we get the following:

# %%
sample_text = "[CLS] We are learning something very cool right now about embedding [SEP] Pay attention"

# %% [markdown]
# Now we can tokenize the text above.

# %%
tokens = tokenizer.tokenize(sample_text)
print(tokens)
# Out:
# ['[CLS]', 'we', 'are', 'learning', 'something', 'very', 'cool', 'right', 'now', 'about', 'em', '##bed', '##ding', '[SEP]', 'pay', 'attention']

# %%
input_ids = tokenizer.convert_tokens_to_ids(tokens)
for i in range(0, 16):
    print(tuple((tokens[i], input_ids[i])))
# Out:
# ('[CLS]', 101)
# ('we', 2057)
# ('are', 2024)
# ('learning', 4083)
# ('something', 2242)
# ('very', 2200)
# ('cool', 4658)
# ('right', 2157)
# ('now', 2085)
# ('about', 2055)
# ('em', 7861)
# ('##bed', 8270)
# ('##ding', 4667)
# ('[SEP]', 102)
# ('pay', 3477)
# ('attention', 3086)

# %%
with torch.no_grad():
    # ids -> hidden state vectors
    input_tensor = torch.LongTensor(input_ids).cuda().view(-1,1)
    input_mask = torch.LongTensor(input_mask).cuda().view(-1,1)
    input_type_ids = torch.LongTensor(input_type_ids).cuda().view(-1,1)
    
    encoded_layers, _ = model(input_tensor, token_type_ids=input_type_ids, attention_mask=input_mask)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-25-0ca73fd5ae0c> in <module>
#       2     # ids -> hidden state vectors
#       3     input_tensor = torch.LongTensor(input_ids).cuda().view(-1,1)
# ----> 4     input_mask = torch.LongTensor(input_mask).cuda().view(-1,1)
#       5     input_type_ids = torch.LongTensor(input_type_ids).cuda().view(-1,1)
#       6
#
# NameError: name 'input_mask' is not defined

# %%
# Define example sentence with multiple meanings of the word "bank"
text = "After stealing money from the bank vault, the bank robber was seen " \
       "fishing on the Mississippi river bank."

# Add the special tokens.
marked_text = "[CLS] " + text + " [SEP]"

# Split the sentence into tokens.
tokenized_text = tokenizer.tokenize(marked_text)

indexed_tokens = tokenizer.convert_tokens_to_ids(tokenized_text)

# Mark each of the 22 tokens as belonging to sentence "1".
segments_ids = [1] * len(tokenized_text)

# %%
# Convert inputs to PyTorch tensors
tokens_tensor = torch.tensor([indexed_tokens])
segments_tensors = torch.tensor([segments_ids])

# %%
from bert_serving.client import BertClient
bc = BertClient()

# %%
sample = ["We are learning something very cool right now", "Pay attention"]
embedding = bc.encode(sample)

# %%
import numpy as np
from sklearn.metrics.pairwise import cosine_similarity
print(cosine_similarity([embedding[0]], [embedding[1]])[0][0])
print(cosine_similarity([embedding[0]], [embedding[0]])[0][0])
# Out:
# 0.5538108
# 1.0000001

# %%
embedding[0]
# Out:
# array([ 7.76866972e-02, -3.24376851e-01,  1.08688269e-02,  2.16468170e-01,
#         4.34082925e-01, -3.97152722e-01, -1.02522179e-01,  8.51855278e-01,
#        -2.14468688e-01, -5.11398852e-01,  2.00513691e-01, -4.32051234e-02,
#         8.13675672e-02,  4.80618179e-01, -2.45117947e-01,  7.56960034e-01,
#        -4.63516146e-01, -1.32480785e-01,  1.58990890e-01,  4.52834427e-01,
#        -8.32417309e-01,  1.62431151e-02, -2.33785823e-01,  5.35807550e-01,
#         1.56863540e-01,  3.35294425e-01, -1.32812440e-01,  4.23749626e-01,
#         4.17029932e-02, -2.21439153e-01,  6.90139472e-01,  4.93629158e-01,
#         3.96681249e-01, -3.67993653e-01, -3.77100408e-01,  3.01529348e-01,
#         1.98715910e-01, -9.17276293e-02,  2.55951583e-01, -9.95296687e-02,
#         2.88058966e-01, -2.36471266e-01,  5.02044916e-01,  3.63670826e-01,
#         4.40733045e-01, -1.40740082e-01,  2.93695658e-01,  6.30217314e-01,
#         4.94025052e-01, -1.57640278e-01,  5.83178043e-01, -5.88550627e-01,
#         1.97022706e-02,  1.69512779e-01,  1.94498152e-01, -4.47582491e-02,
#        -1.97351918e-01, -2.97264699e-02,  2.80198250e-02, -3.93332653e-02,
#         1.61900491e-01, -3.08867246e-02, -2.51226276e-01,  4.94096607e-01,
#         3.80743802e-01, -1.73588470e-01, -2.99467444e-02, -4.19222564e-02,
#         7.45836720e-02, -3.31501842e-01, -1.39719054e-01, -3.03127587e-01,
#         1.18848905e-01, -3.59685868e-02, -3.43716323e-01,  1.30520016e-01,
#        -5.24343625e-02, -5.72097413e-02, -2.89063044e-02, -3.60410452e-01,
#         3.22771102e-01, -6.18782759e-01,  5.36201173e-04,  4.16328758e-02,
#         1.64067790e-01,  5.07583797e-01,  6.61010742e-01, -1.50965333e-01,
#         2.95938075e-01, -2.57945985e-01, -1.31587297e-01,  4.31575060e-01,
#        -7.57446229e-01, -6.81796521e-02, -7.54167438e-01, -3.10088366e-01,
#        -3.69056314e-01, -8.00975204e-01,  5.05492747e-01,  1.02767491e+00,
#        -1.97710857e-01, -1.53429469e-03, -2.86881864e-01, -5.05311489e-02,
#        -3.46843037e-03, -8.21837604e-01, -3.21584314e-01, -1.68692157e-01,
#        -2.97988743e-01, -4.91261721e-01, -5.61795533e-01,  2.11936943e-02,
#         1.74027346e-02, -3.31426144e-01,  2.95025650e-02,  3.79828036e-01,
#        -5.93686402e-01, -8.01218450e-02,  2.56924424e-02, -2.57514298e-01,
#         2.97800839e-01, -1.87815167e-02,  1.02067530e-01, -2.05648899e-01,
#        -3.36592346e-01,  1.27771765e-01, -9.69549417e-02, -3.14440846e-01,
#         3.63058031e-01,  6.46519661e-01,  4.67758588e-02, -2.82968462e-01,
#         5.75691104e-01,  3.63933332e-02, -3.98498237e-01,  1.68382883e-01,
#        -3.31390202e-01,  6.75122663e-02, -6.78518414e-01,  5.46759441e-02,
#         1.02499343e-01, -3.06309372e-01, -7.33977780e-02,  3.17036331e-01,
#         4.59413350e-01, -4.21012163e-01,  3.88326436e-01, -2.86621843e-02],
#       dtype=float32)

# %%
from sentence_transformers import SentenceTransformer
model = SentenceTransformer('bert-base-nli-mean-tokens')

# %%
sample = ["We are learning something very cool right now", "Pay attention"]
sentence_embeddings = model.encode(sample)

# %%
sample2 = ["We are learning something very cool right now. Pay attention"]
sentence_embeddings2 = model.encode(sample2)

# %%
average = np.mean([sentence_embeddings[0], sentence_embeddings[1]], axis = 0)

# %%
big_sentence = sentence_embeddings2

# %%
cosine_similarity(big_sentence, [average])
# Out:
# array([[0.91829956]], dtype=float32)

# %%
print(cosine_similarity([sentence_embeddings[0]], [sentence_embeddings[1]])[0][0])
print(cosine_similarity([sentence_embeddings[0]], [sentence_embeddings[0]])[0][0])
# Out:
# 0.64304817
# 1.0000001
